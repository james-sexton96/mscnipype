# %%
####################################################### IMPORT #########################################################
from os.path import join as opj
import os
import nipype.interfaces.utility as niu
from nipype.interfaces.fsl import (BET, ExtractROI, FAST, FLIRT,
                                   FNIRT, ApplyWarp, MCFLIRT,
                                   MotionOutliers, BinaryMaths, ImageMeants,
                                   DilateImage)
from nipype.interfaces.fsl.maths import MathsCommand
from nipype.interfaces import fsl
from nipype.interfaces.afni import (Despike, TShift, Volreg,
                                    TProject, MaskTool, Refit,
                                    Fourier, Detrend, Maskave,
                                    MaskTool, TStat, Localstat,
                                    Bandpass, Calc, BlurInMask)
from nipype.interfaces.ants import (Registration, ApplyTransforms)

from nipype.interfaces.io import DataSink, SelectFiles
from nipype.interfaces.utility import IdentityInterface, Function
from nipype import Workflow, Node
from nipype.interfaces.c3 import C3dAffineTool

# this is a quick function to tell python how to find the right file from the segmentation function
pickindex = lambda x, i: x[i]

################## DEFINES THE MATLAB SCRIPT TO BPF AND DETREND CSF ############################

# This is a useful way to call in matlab to do something to a result from nipype, in this case -
# I need to bandpass and detrend regressors so they don't re-introduce noise

from nipype.interfaces.matlab import MatlabCommand
from nipype.interfaces.base import TraitedSpec, BaseInterface, BaseInterfaceInputSpec, File
import os
from string import Template


class bpfdtcsfInputSpec(BaseInterfaceInputSpec):
    in_file = File(exists=True, mandatory=True)
    out_file = File('CSF_bpfdt.1D', usedefault=True)


class bpfdtcsfOutputSpec(TraitedSpec):
    out_file = File(exists=True)


class CSFbpfdt(BaseInterface):
    input_spec = bpfdtcsfInputSpec
    output_spec = bpfdtcsfOutputSpec

    def _run_interface(self, runtime):
        d = dict(in_file=self.inputs.in_file,
                 out_file=self.inputs.out_file)
        # this is your MATLAB code template
        script = Template("""oned = load('$in_file');
        bpf = bandpass(oned, [0.01 0.08]);
        bpfdt = detrend(bpf, 2);
        save('$out_file', 'bpfdt', '-ascii');
        exit;""").substitute(d)

        mlab = MatlabCommand(script=script, mfile=True)
        result = mlab.run()

        return result.runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        outputs['out_file'] = os.path.abspath('CSF_bpfdt.1D')
        return outputs


############### DEFINES THE SAME PROCESS AS ABOVE BUT DEDICATED FOR MOTION CORRECTION  ####################


class bpfdtInputSpec(BaseInterfaceInputSpec):
    in_file = File(exists=True, mandatory=True)
    out_file = File('MOCO_bpfdt.1D', usedefault=True)


class bpfdtOutputSpec(TraitedSpec):
    out_file = File(exists=True)


class MOCObpfdt(BaseInterface):
    input_spec = bpfdtInputSpec
    output_spec = bpfdtOutputSpec

    def _run_interface(self, runtime):
        d = dict(in_file=self.inputs.in_file,
                 out_file=self.inputs.out_file)
        # this is your MATLAB code template
        script = Template("""oned = load('$in_file');
        bpf = bandpass(oned, [0.01 0.08]);
        bpfdt = detrend(bpf, 2);
        save('$out_file', 'bpfdt', '-ascii');
        exit;""").substitute(d)

        mlab = MatlabCommand(script=script, mfile=True)
        result = mlab.run()

        return result.runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        outputs['out_file'] = os.path.abspath('MOCO_bpfdt.1D')
        return outputs


############### DEFINES FUNCTION TO CONCATENATE REGRESSORS INTO SINGLE MATRIX  ####################


class concatInputSpec(BaseInterfaceInputSpec):
    in_file_a = File(exists=True, mandatory=True)
    in_file_b = File(exists=True, mandatory=True)
    out_file = File('regmodel.1D', usedefault=True)


class concatOutputSpec(TraitedSpec):
    out_file = File(exists=True)


class ConcatModel(BaseInterface):
    input_spec = concatInputSpec
    output_spec = concatOutputSpec

    def _run_interface(self, runtime):
        a = dict(in_file_a=self.inputs.in_file_a,
                 in_file_b=self.inputs.in_file_b,
                 out_file=self.inputs.out_file)
        # this is your MATLAB code template
        conscript = Template("""moco = load('$in_file_a');
        csf = load('$in_file_b');
        regmodel = horzcat(csf, moco);
        save('$out_file', 'regmodel', '-ascii');
        exit;""").substitute(a)

        z = MatlabCommand(script=conscript, mfile=True)
        res = z.run()

        return res.runtime

    def _list_outputs(self):
        outputs = self._outputs().get()
        outputs['out_file'] = os.path.abspath('regmodel.1D')
        return outputs


########################################################################################################################
#
#  $$$$$$$\                      $$$$$$$\
#  $$  __$$\                     $$  __$$\
#  $$ |  $$ | $$$$$$\   $$$$$$\  $$ |  $$ | $$$$$$\   $$$$$$\   $$$$$$$\
#  $$$$$$$  |$$  __$$\ $$  __$$\ $$$$$$$  |$$  __$$\ $$  __$$\ $$  _____|
#  $$  ____/ $$ |  \__|$$$$$$$$ |$$  ____/ $$ |  \__|$$ /  $$ |$$ /
#  $$ |      $$ |      $$   ____|$$ |      $$ |      $$ |  $$ |$$ |
#  $$ |      $$ |      \$$$$$$$\ $$ |      $$ |      \$$$$$$  |\$$$$$$$\
#  \__|      \__|       \_______|\__|      \__|       \______/  \_______|
#
#
#
############################################ INPUT SOURCING FOR MULTIPLE PT's AND SCANS #################################

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')
experiment_dir = '/Users/James/Desktop/preproc/'
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers, input your subject numbers. 
# subject_list = ['01', '02', '03', '04', '05', '06', '07', '08']
# subject_list = ['09', '10', '11', '12', '13', '14', '15', '16']
# subject_list = ['17', '18', '19', '20', '21', '22', '23', '24']
# subject_list = ['25', '26', '27', '28', '29', '30', '31', '32', '33']
# subject_list = ['34', '35', '36', '37', '38', '39', '40']
# subject_list = ['41', '42', '43', '44', '45']
# subject_list = ['46', '47', '48']
# subject_list = ['49']
# subject_list = ['50']

# list of session identifiers
# ses_list = ['1']
# ses_list = ['2']
# ses_list = ['1', '2']

preproc = Workflow(name='preproc')
preproc.base_dir = '/Users/James/Desktop/preproc/'

################################################ Input - Output Stream #################################################

# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'ses']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('ses', ses_list)]

# SelectFiles - to grab the data (alternative to DataGrabber)
anat_file = opj('sub-ID{subject_id}', 'ses-{ses}', 'anat', 'sub-ID{subject_id}_ses-{ses}*.nii.gz')
func_file = opj('sub-ID{subject_id}', 'ses-{ses}', 'func', 'sub-ID{subject_id}_ses-{ses}*.nii.gz')

templates = {'anat': anat_file,
             'func': func_file}
selectfiles = Node(SelectFiles(templates,
                               base_directory='/Users/James/Psilodep/BIDS/'),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('ses', 'ses')])])

#################################################### Functional_Processing #############################################

#
# ███████╗██████╗ ██████╗  ██████╗  ██████╗
# ██╔════╝██╔══██╗██╔══██╗██╔═══██╗██╔════╝
# █████╗  ██████╔╝██████╔╝██║   ██║██║
# ██╔══╝  ██╔═══╝ ██╔══██╗██║   ██║██║
# ██║     ██║     ██║  ██║╚██████╔╝╚██████╗
# ╚═╝     ╚═╝     ╚═╝  ╚═╝ ╚═════╝  ╚═════╝

#########################################################################################################################

fproc = Workflow(name='fproc')

# ExtractROI - skip dummy scans
trim = Node(ExtractROI(t_min=3,
                       t_size=477,
                       output_type='NIFTI_GZ'),
            name="trim")

# 3dDespike - despike
despike = Node(Despike(outputtype='NIFTI_GZ', args='-NEW'),
               name="despike")
fproc.connect([(trim, despike, [('roi_file', 'in_file')])])
preproc.connect([(selectfiles, fproc, [('func', 'trim.in_file')])])

# 3dTshift - slice time correction
slicetime = Node(TShift(outputtype='NIFTI_GZ',
                        tpattern='alt+z2'),
                 name="slicetime")
fproc.connect([(despike, slicetime, [('out_file', 'in_file')])])

# 3dVolreg - correct motion and output 1d matrix
moco = Node(Volreg(outputtype='NIFTI_GZ',
                   interp='Fourier',
                   zpad=4,
                   args='-twopass'),
            name="moco")
fproc.connect([(slicetime, moco, [('out_file', 'in_file')])])

moco_bpfdt = Node(MOCObpfdt(), name='moco_bpfdt')
fproc.connect([(moco, moco_bpfdt, [('oned_file', 'in_file')])])

############################################## Registration - FSL/ANTs #################################################
#

#  ██████╗ ██████╗ ██████╗ ███████╗ ██████╗
# ██╔════╝██╔═══██╗██╔══██╗██╔════╝██╔════╝
# ██║     ██║   ██║██████╔╝█████╗  ██║  ███╗
# ██║     ██║   ██║██╔══██╗██╔══╝  ██║   ██║
# ╚██████╗╚██████╔╝██║  ██║███████╗╚██████╔╝
#  ╚═════╝ ╚═════╝ ╚═╝  ╚═╝╚══════╝ ╚═════╝

########################################################################################################################

coreg = Workflow(name='coreg')

# BET - structural data brain extraction
bet_anat = Node(BET(output_type='NIFTI_GZ',
                    frac=0.37,
                    robust=True), name="bet_anat")

# FSL segmentation process to get WM map
seg = Node(FAST(bias_iters=6,
                img_type=1,
                output_biascorrected=True,
                output_type='NIFTI_GZ'), name="seg")
coreg.connect([(bet_anat, seg, [('out_file', 'in_files')])])

# functional to structural bits
mean = Node(MCFLIRT(mean_vol=True,
                    output_type='NIFTI_GZ'), name="mean")

func2struc = Node(FLIRT(cost='bbr',
                        dof=6,
                        output_type='NIFTI_GZ'), name='func2struc')
coreg.connect([(seg, func2struc, [('restored_image', 'reference')])])
coreg.connect([(mean, func2struc, [('mean_img', 'in_file')])])
coreg.connect([(seg, func2struc, [(('tissue_class_files', pickindex, 2), 'wm_seg')])])

f2s_c3d = Node(C3dAffineTool(itk_transform=True,
                             fsl2ras=True), name='f2s_c3d')
coreg.connect([(func2struc, f2s_c3d, [('out_matrix_file', 'transform_file')])])
coreg.connect([(mean, f2s_c3d, [('mean_img', 'source_file')])])
coreg.connect([(seg, f2s_c3d, [('restored_image', 'reference_file')])])

# Functional to structural registration via ANTs non-linear registration

reg = Node(Registration(fixed_image='/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',
                        transforms=['Affine', 'SyN'],
                        transform_parameters=[(0.1,), (0.1, 3.0, 0.0)],
                        number_of_iterations=[[1500, 1000, 1000], [100, 70, 50, 20]],
                        dimension=3,
                        write_composite_transform=True,
                        collapse_output_transforms=True,
                        metric=['MI'] + ['CC'],
                        metric_weight=[1] * 2,
                        radius_or_number_of_bins=[32] + [4],
                        convergence_threshold=[1.e-8, 1.e-9],
                        convergence_window_size=[20] + [10],
                        smoothing_sigmas=[[2, 1, 0], [4, 2, 1, 0]],
                        sigma_units=['vox'] * 2,
                        shrink_factors=[[4, 2, 1], [6, 4, 2, 1]],
                        use_histogram_matching=[False] + [True],
                        use_estimate_learning_rate_once=[True, True],
                        output_warped_image=True),
           name='reg')

coreg.connect([(seg, reg, [('restored_image', 'moving_image')])])

merge1 = Node(niu.Merge(2), iterfield=['in2'], name='merge1')
coreg.connect([(f2s_c3d, merge1, [('itk_transform', 'in2')])])
coreg.connect([(reg, merge1, [('composite_transform', 'in1')])])

warp = Node(ApplyTransforms(reference_image='/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',
                            input_image_type=3), name='warp')
coreg.connect([(moco, warp, [('out_file', 'input_image')])])
coreg.connect([(merge1, warp, [('out', 'transforms')])])

# This code would be for FSL ONLY non-linear registration. This does not perform as well as ANTs, so use the ANTs reg above if possible

# see https://www.ncbi.nlm.nih.gov/pubmed/19195496 for performance of ANTs SyN used here

# flirt1 = Node(FLIRT(reference = '/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',
#                     output_type = 'NIFTI_GZ'), name = "flirt1")
# coreg.connect([(seg, flirt1, [('restored_image', 'in_file')])])
#
# flirt2mni = Node(FLIRT(reference = '/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',
#                        output_type = 'NIFTI_GZ'), name = "flirt2mni")
# coreg.connect([(seg, flirt2mni, [('restored_image', 'in_file')])])
# coreg.connect([(flirt1, flirt2mni, [('out_matrix_file', 'in_matrix_file')])])
#
# fnirt2mni = Node(FNIRT(fieldcoeff_file = True,
#                        ref_file = '/usr/local/fsl/data/standard/MNI152_T1_2mm.nii.gz',
#                        subsampling_scheme = [8,4,2,2],
#                        output_type = 'NIFTI_GZ'), name = "fnirt2mni")
# coreg.connect([(flirt2mni, fnirt2mni, [('out_matrix_file', 'affine_file')])])
# coreg.connect([(seg, fnirt2mni, [('restored_image', 'in_file')])])
#
#
# applywarp = Node(ApplyWarp(ref_file = '/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz',
#                            output_type = 'NIFTI_GZ',
#                            args = '-v'), name = "applywarp")
# coreg.connect([(func2struc, applywarp, [('out_matrix_file', 'premat')])])
# coreg.connect([(fnirt2mni, applywarp, [('fieldcoeff_file', 'field_file')])])

# Connect outputs from other workflows here
preproc.connect([(selectfiles, coreg, [('anat', 'bet_anat.in_file')])])
preproc.connect([(fproc, coreg, [('moco.out_file', 'mean.in_file')])])


############################################## ######################### #################################################
#  /$$$$$$                                /$$      
# /$$__  $$                              | $$      
#| $$  \__/  /$$$$$$$  /$$$$$$  /$$   /$$| $$$$$$$ 
#|  $$$$$$  /$$_____/ /$$__  $$| $$  | $$| $$__  $$
# \____  $$| $$      | $$  \__/| $$  | $$| $$  \ $$
# /$$  \ $$| $$      | $$      | $$  | $$| $$  | $$
#|  $$$$$$/|  $$$$$$$| $$      |  $$$$$$/| $$$$$$$/
# \______/  \_______/|__/       \______/ |_______/ 
############################################## ######################### #################################################
# Motion scrubbing for the censoring of high motion time points

scrub = Workflow(name='scrub')

# Generate the Scrubbing Regressor
scrub_metrics = Node(MotionOutliers(dummy = 4,
                            out_file = 'FD_outliers.1D',
                            metric='fd',
                            threshold=0.4), name="scrub_metrics")

#regress out timepoints
scrub_frames = Node(Bandpass(highpass=0,
                         lowpass=99999,
                         outputtype='NIFTI_GZ'), name='scrub_frames')
scrub.connect([(scrub_metrics, scrub_frames, [('out_file', 'orthogonalize_file')])])
preproc.connect([(coreg, scrub, [('warp.output_image', 'scrub_frames.in_file')])])
preproc.connect([(selectfiles, scrub, [('func', 'scrub_metrics.in_file')])])


# mean image for remeaning after bandpass
premean = Node(TStat(args='-mean',
                   outputtype='NIFTI_GZ'), name='premean')
# remean the image
remean2 = Node(Calc(expr='a+b',
                    outputtype='NIFTI_GZ'), name='remean2')
scrub.connect([(scrub_frames, remean2, [('out_file', 'in_file_a')])])
scrub.connect([(premean, remean2, [('out_file', 'in_file_b')])])
preproc.connect([(coreg, scrub, [('warp.output_image', 'premean.in_file')])])

############################################## ######################### #################################################

#  ____  ____   ___  ____  ____  ____  ____   __   ____  ____
# (  _ \(  __) / __)(  _ \(  __)/ ___)/ ___) /  \ (  _ \/ ___)
#  )   / ) _) ( (_ \ )   / ) _) \___ \\___ \(  O ) )   /\___ \
# (__\_)(____) \___/(__\_)(____)(____/(____/ \__/ (__\_)(____/

############################################## ######################### #################################################
# Creates nuisance regressors like local white matter and cerebrospinal fluid signal
regressors = Workflow(name='regressors')

# Using registered structural image to create the masks for both WM and CSF
regbet = Node(BET(robust=True,
                  frac=0.37,
                  output_type='NIFTI_GZ'), name='regbet')

regseg = Node(FAST(img_type=1,
                   output_type='NIFTI_GZ',
                   no_pve=True,
                   no_bias=True,
                   segments=True), name='regseg')
regressors.connect([(regbet, regseg, [('out_file', 'in_files')])])
preproc.connect([(coreg, regressors, [('reg.warped_image', 'regbet.in_file')])])

############# CSF Regressor

# subtract subcortical GM from the CSF mask
subcortgm = Node(BinaryMaths(operation='sub',
                             operand_file='/Users/James/Psilodep/subcortical_gm_mask/subcortical_gm_mask_bin.nii.gz',
                             output_type='NIFTI_GZ',
                             args='-bin'), name='subcortgm')
regressors.connect([(regseg, subcortgm, [(('tissue_class_files', pickindex, 0), 'in_file')])])

# Fill the mask holes

fillcsf = Node(MaskTool(fill_holes=True,
                        outputtype='NIFTI_GZ'), name='fillcsf')
regressors.connect([(subcortgm, fillcsf, [('out_file', 'in_file')])])

# Erode the mask

erocsf = Node(MaskTool(outputtype='NIFTI_GZ',
                       dilate_inputs='-1'), name='erocsf')
regressors.connect([(fillcsf, erocsf, [('out_file', 'in_file')])])

# Take mean csf signal from functional image
meancsf = Node(ImageMeants(output_type='NIFTI_GZ'), name='meancsf')
regressors.connect([(erocsf, meancsf, [('out_file', 'mask')])])
preproc.connect([(coreg, regressors, [('warp.output_image', 'meancsf.in_file')])])

bpf_dt_csf = Node(CSFbpfdt(), name='bpf_dt_csf')
regressors.connect([(meancsf, bpf_dt_csf, [('out_file', 'in_file')])])

########## Local White Matter

# subtract subcortical gm
subcortgm2 = Node(BinaryMaths(operation='sub',
                              operand_file='/Users/James/Psilodep/subcortical_gm_mask/subcortical_gm_mask_bin.nii.gz',
                              output_type='NIFTI_GZ',
                              args='-bin'), name='subcortgm2')
regressors.connect([(regseg, subcortgm2, [(('tissue_class_files', pickindex, 2), 'in_file')])])

# fill mask
fillwm = Node(MaskTool(fill_holes=True,
                       outputtype='NIFTI_GZ'), name='fillwm')
regressors.connect([(subcortgm2, fillwm, [('out_file', 'in_file')])])

# erod mask
erowm = Node(MaskTool(outputtype='NIFTI_GZ',
                      dilate_inputs='-1'), name='erowm')
regressors.connect([(fillwm, erowm, [('out_file', 'in_file')])])

# generate local wm
localwm = Node(Localstat(neighborhood=('SPHERE', 25),
                         stat='mean',
                         nonmask=True,
                         outputtype='NIFTI_GZ'), name='localwm')
regressors.connect([(erowm, localwm, [('out_file', 'mask_file')])])
preproc.connect([(coreg, regressors, [('warp.output_image', 'localwm.in_file')])])

# bpf local wm
localwm_bpf = Node(Fourier(highpass=0.01,
                           lowpass=0.08,
                           args='-retrend',
                           outputtype='NIFTI_GZ'), name='loacwm_bpf')
regressors.connect([(localwm, localwm_bpf, [('out_file', 'in_file')])])

# detrend local wm

localwm_bpf_dt = Node(Detrend(args='-polort 2',
                              outputtype='NIFTI_GZ'), name='localwm_bpf_dt')
regressors.connect([(localwm_bpf, localwm_bpf_dt, [('out_file', 'in_file')])])

############################################## ######################### #################################################

#  $$$$$$\  $$\       $$$$$$$$\  $$$$$$\  $$\   $$\
# $$  __$$\ $$ |      $$  _____|$$  __$$\ $$$\  $$ |
# $$ /  \__|$$ |      $$ |      $$ /  $$ |$$$$\ $$ |
# $$ |      $$ |      $$$$$\    $$$$$$$$ |$$ $$\$$ |
# $$ |      $$ |      $$  __|   $$  __$$ |$$ \$$$$ |
# $$ |  $$\ $$ |      $$ |      $$ |  $$ |$$ |\$$$ |
# \$$$$$$  |$$$$$$$$\ $$$$$$$$\ $$ |  $$ |$$ | \$$ |
#  \______/ \________|\________|\__|  \__|\__|  \__|

############################################## ######################### #################################################

# create a mask for blurring filtering, and detrending

clean = Workflow(name='clean')

mask = Node(BET(mask=True,
                functional=True), name='mask')

mean_mask = Node(MCFLIRT(mean_vol=True,
                         output_type='NIFTI_GZ'), name="mean_mask")

dilf = Node(DilateImage(operation='max',
                        output_type='NIFTI_GZ'), name='dilf')
clean.connect([(mask, dilf, [('mask_file', 'in_file')])])
preproc.connect([(scrub, clean, [('remean2.out_file', 'mask.in_file')])])

fill = Node(MaskTool(in_file='/usr/local/fsl/data/standard/MNI152_T1_2mm_brain_mask.nii.gz',
                     fill_holes=True,
                     outputtype='NIFTI_GZ'), name='fill')

axb = Node(Calc(expr='a*b',
                outputtype='NIFTI_GZ'), name='axb')
clean.connect([(dilf, axb, [('out_file', 'in_file_a')])])
clean.connect([(fill, axb, [('out_file', 'in_file_b')])])

bxc = Node(Calc(expr='ispositive(a)*b',
                outputtype='NIFTI_GZ'), name='bxc')
clean.connect([(mean_mask, bxc, [('mean_img', 'in_file_a')])])
clean.connect([(axb, bxc, [('out_file', 'in_file_b')])])
preproc.connect([(scrub, clean, [('remean2.out_file', 'mean_mask.in_file')])])

#### BLUR, FOURIER, DETREND

blurinmask = Node(BlurInMask(fwhm=6,
                             outputtype='NIFTI_GZ'), name='blurinmask')
clean.connect([(bxc, blurinmask, [('out_file', 'mask')])])
preproc.connect([(scrub, clean, [('remean2.out_file', 'blurinmask.in_file')])])

fourier = Node(Fourier(highpass=0.01,
                       lowpass=0.08,
                       retrend=True,
                       outputtype='NIFTI_GZ'), name='fourier')
clean.connect([(blurinmask, fourier, [('out_file', 'in_file')])])

tstat = Node(TStat(args='-mean',
                   outputtype='NIFTI_GZ'), name='tstat')
clean.connect([(fourier, tstat, [('out_file', 'in_file')])])

detrend = Node(Detrend(args='-polort 2',
                       outputtype='NIFTI_GZ'), name='detrend')
clean.connect([(fourier, detrend, [('out_file', 'in_file')])])

remean = Node(Calc(expr='a+b',
                   outputtype='NIFTI_GZ'), name='remean')
clean.connect([(detrend, remean, [('out_file', 'in_file_a')])])
clean.connect([(tstat, remean, [('out_file', 'in_file_b')])])

concat = Node(ConcatModel(), name='concat')

# Removes nuisance regressors via regression function
clean_rs = Node(Bandpass(highpass=0,
                         lowpass=99999,
                         outputtype='NIFTI_GZ'), name='clean_rs')

clean.connect([(concat, clean_rs, [('out_file', 'orthogonalize_file')])])

remean1 = Node(Calc(expr='a+b',
                    outputtype='NIFTI_GZ'), name='remean1')
clean.connect([(clean_rs, remean1, [('out_file', 'in_file_a')])])
clean.connect([(tstat, remean1, [('out_file', 'in_file_b')])])

preproc.connect([(regressors, clean, [('bpf_dt_csf.out_file', 'concat.in_file_a')])])
preproc.connect([(fproc, clean, [('moco_bpfdt.out_file', 'concat.in_file_b')])])

preproc.connect([(regressors, clean, [('localwm_bpf_dt.out_file', 'clean_rs.orthogonalize_dset')])])
clean.connect([(remean, clean_rs, [('out_file', 'in_file')])])

##################################################### OUTPUTS ##########################################################

# connect what you want to the datasink

# preproc.connect([(coreg, datasink, [('func2struc.out_file', 'coreg.@func2struc')])])
# preproc.connect([(coreg, datasink, [('reg.warped_image', 'coreg.@struc2mni')])])
# preproc.connect([(coreg, datasink, [('warp.output_image', 'coreg.@func2mni')])])
# preproc.connect([(scrub, datasink, [('scrub_metrics.out_file', 'scrub.@scrub_times')])])
# preproc.connect([(scrub, datasink, [('scrub_metrics.out_metric_values', 'scrub.@FD_values')])])
# # preproc.connect([(regressors, datasink, [('scrub.out_metric_plot', 'scrub.@scrub_plot')])])
# preproc.connect([(fproc, datasink, [('moco_bpfdt.out_file', 'regressors.@Motion_regressor')])])
# preproc.connect([(regressors, datasink, [('bpf_dt_csf.out_file', 'regressors.@CSF_regressor')])])
# preproc.connect([(regressors, datasink, [('localwm_bpf_dt.out_file', 'regressors.@LocalWM_regressor')])])
# preproc.connect([(regressors, datasink, [('concat.out_file', 'regressors.@concat_model')])])
# preproc.connect([(regressors, datasink, [('clean_rs.out_file', 'regressors.@regressed_demeaned_rsfmri')])])
# preproc.connect([(clean, datasink, [('remean1.out_file', 'preprocessed.@preproc_rsfmri')])])

# Write graphs to visualize workflows

# fproc.write_graph(graph2use='flat', format='png', simple_form=True)
# fproc.write_graph(graph2use='colored', format='png', simple_form=True)

# coreg.write_graph(graph2use='flat', format='png', simple_form=True)
# coreg.write_graph(graph2use='colored', format='png', simple_form=True)

# scrub.write_graph(graph2use='flat', format='png', simple_form=True)
# scrub.write_graph(graph2use='colored', format='png', simple_form=True)

# regressors.write_graph(graph2use='flat', format='png', simple_form=True)
# regressors.write_graph(graph2use='colored', format='png', simple_form=True)

preproc.write_graph(graph2use='flat', format='png', simple_form=True)
preproc.write_graph(graph2use='colored', format='png', simple_form=True)

# preproc.run('MultiProc', plugin_args={'n_procs' : 6})
# Out:
# 200511-15:44:26,39 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/James/Desktop/preproc/preproc/graph.png (graph2use=flat, simple_form=True).
# 200511-15:44:26,192 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/James/Desktop/preproc/preproc/graph.png (graph2use=colored, simple_form=True).
# '/Users/James/Desktop/preproc/preproc/graph.png'

# %%
# preproc.run('MultiProc', plugin_args={'n_procs' : 4})
# Out:
# 200511-15:44:27,109 nipype.workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging', 'monitoring']
# 200511-15:44:27,149 nipype.workflow INFO:
# 	 Running in parallel.
# 200511-15:44:27,154 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 6/6.
# 200511-15:44:27,232 nipype.workflow INFO:
# 	 [Job 35] Cached (preproc.clean.fill).
# 200511-15:44:27,232 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/Users/James/Desktop/preproc/preproc/_ses_1_subject_id_42/selectfiles".
# 200511-15:44:27,245 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200511-15:44:27,253 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 200511-15:44:29,154 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc.selectfiles).
# 200511-15:44:29,157 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 6/6.
# 200511-15:44:29,231 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.bet_anat".
# 200511-15:44:29,231 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.scrub.scrub_metrics" in "/Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/scrub_metrics".
# 200511-15:44:29,235 nipype.workflow INFO:
# 	 [Job 13] Cached (preproc.fproc.trim).
# 200511-15:44:29,236 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.bet_anat" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/bet_anat".
# 200511-15:44:29,239 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.bet_anat".
# 200511-15:44:29,242 nipype.workflow INFO:
# 	 [Node] Running "scrub_metrics" ("nipype.interfaces.fsl.utils.MotionOutliers"), a CommandLine Interface with command:
# fsl_motion_outliers --dummy=4 -i /Users/James/Psilodep/BIDS/sub-ID42/ses-1/func/sub-ID42_ses-1_resting_state_fmri.nii.gz --fd -o FD_outliers.1D -p sub-ID42_ses-1_resting_state_fmri_metrics.png -s sub-ID42_ses-1_resting_state_fmri_metrics.txt --thresh=0.4
# 200511-15:44:29,248 nipype.workflow INFO:
# 	 [Node] Running "bet_anat" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Users/James/Psilodep/BIDS/sub-ID42/ses-1/anat/sub-ID42_ses-1_T1_MPRAGE_T1.nii.gz /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/bet_anat/sub-ID42_ses-1_T1_MPRAGE_T1_brain.nii.gz -f 0.37 -R
# 200511-15:44:31,156 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.coreg.bet_anat
#                        * preproc.scrub.scrub_metrics
# 200511-15:44:31,203 nipype.workflow INFO:
# 	 [Job 14] Cached (preproc.fproc.despike).
# 200511-15:44:33,197 nipype.workflow INFO:
# 	 [Job 15] Cached (preproc.fproc.slicetime).
# 200511-15:44:35,198 nipype.workflow INFO:
# 	 [Job 16] Cached (preproc.preproc.fproc.moco).
# 200511-15:44:37,164 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.coreg.bet_anat
#                        * preproc.scrub.scrub_metrics
# 200511-15:44:37,203 nipype.workflow INFO:
# 	 [Job 17] Cached (preproc.coreg.mean).
# 200511-15:44:37,206 nipype.workflow INFO:
# 	 [Job 33] Cached (preproc.fproc.moco_bpfdt).
# 200511-15:44:39,166 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.coreg.bet_anat
#                        * preproc.scrub.scrub_metrics
# 200511-15:44:40,229 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.bet_anat".
# 200511-15:44:41,170 nipype.workflow INFO:
# 	 [Job 2] Completed (preproc.coreg.bet_anat).
# 200511-15:44:41,173 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.scrub.scrub_metrics
# 200511-15:44:41,230 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.seg".
# 200511-15:44:41,235 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.seg" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg".
# 200511-15:44:41,239 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.seg".
# 200511-15:44:41,250 nipype.workflow INFO:
# 	 [Node] Running "seg" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -I 6 -t 1 -B -S 1 /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg/sub-ID42_ses-1_T1_MPRAGE_T1_brain.nii.gz
# 200511-15:44:43,175 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.coreg.seg
#                        * preproc.scrub.scrub_metrics
# 200511-15:46:19,824 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 200511-15:46:19,826 nipype.workflow WARNING:
# 	 [Node] Error on "preproc.scrub.scrub_metrics" (/Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/scrub_metrics)
# 200511-15:46:21,295 nipype.workflow ERROR:
# 	 Node scrub_metrics.a0 failed to run on host Jamess-MBP.broadband.
# 200511-15:46:21,296 nipype.workflow ERROR:
# 	 Saving crash info to /Users/James/PycharmProjects/Psilodep/crash-20200511-154621-James-scrub_metrics.a0-67c2ed1f-1e49-4529-bc9a-2b3e594fee4c.pklz
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 500, in aggregate_outputs
#     setattr(outputs, key, val)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/traits_extension.py", line 329, in validate
#     value = super(File, self).validate(objekt, name, value, return_pathlike=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/traits_extension.py", line 134, in validate
#     self.error(objekt, name, str(value))
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/traits/base_trait_handler.py", line 77, in error
#     object, name, self.full_info(object, name, value), value
# traits.trait_errors.TraitError: The 'out_file' trait of a MotionOutliersOutputSpec instance must be a pathlike object or string representing an existing file, but a value of '/Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/scrub_metrics/FD_outliers.1D' <class 'str'> was specified.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run
#     result = self._run_interface(execute=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface
#     return self._run_command(execute)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 399, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 507, in aggregate_outputs
#     raise FileNotFoundError(msg)
# FileNotFoundError: No such file or directory '/Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/scrub_metrics/FD_outliers.1D' for output 'out_file' of a MotionOutliers interface
#
# 200511-15:46:21,299 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.seg
# 200511-15:48:33,528 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.seg".
# 200511-15:48:35,494 nipype.workflow INFO:
# 	 [Job 3] Completed (preproc.coreg.seg).
# 200511-15:48:35,497 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 6/6.
# 200511-15:48:35,535 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.reg".
# 200511-15:48:35,540 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.func2struc" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/func2struc".
# 200511-15:48:35,541 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.reg" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/reg".
# 200511-15:48:35,545 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.reg".
# 200511-15:48:35,553 nipype.workflow INFO:
# 	 [Node] Running "func2struc" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/mean/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_mcf_mean_reg.nii.gz -ref /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg/sub-ID42_ses-1_T1_MPRAGE_T1_brain_restore.nii.gz -out sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_mcf_mean_reg_flirt.nii.gz -omat sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_mcf_mean_reg_flirt.mat -cost bbr -dof 6
# 200511-15:48:35,558 nipype.workflow INFO:
# 	 [Node] Running "reg" ("nipype.interfaces.ants.registration.Registration"), a CommandLine Interface with command:
# antsRegistration --collapse-output-transforms 1 --dimensionality 3 --initialize-transforms-per-stage 0 --interpolation Linear --output [ transform, transform_Warped.nii.gz ] --transform Affine[ 0.1 ] --metric MI[ /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz, /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg/sub-ID42_ses-1_T1_MPRAGE_T1_brain_restore.nii.gz, 1, 32 ] --convergence [ 1500x1000x1000, 1e-08, 20 ] --smoothing-sigmas 2.0x1.0x0.0vox --shrink-factors 4x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 0 --transform SyN[ 0.1, 3.0, 0.0 ] --metric CC[ /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz, /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg/sub-ID42_ses-1_T1_MPRAGE_T1_brain_restore.nii.gz, 1, 4 ] --convergence [ 100x70x50x20, 1e-09, 10 ] --smoothing-sigmas 4.0x2.0x1.0x0.0vox --shrink-factors 6x4x2x1 --use-estimate-learning-rate-once 1 --use-histogram-matching 1 --winsorize-image-intensities [ 0.0, 1.0 ]  --write-composite-transform 1
# 200511-15:48:37,497 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.coreg.func2struc
#                        * preproc.coreg.reg
# 200511-15:48:39,539 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.func2struc".
# 200511-15:48:41,505 nipype.workflow INFO:
# 	 [Job 18] Completed (preproc.coreg.func2struc).
# 200511-15:48:41,507 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.reg
# 200511-15:48:41,552 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.f2s_c3d".
# 200511-15:48:41,555 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.f2s_c3d" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/f2s_c3d".
# 200511-15:48:41,557 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.f2s_c3d".
# 200511-15:48:41,564 nipype.workflow INFO:
# 	 [Node] Running "f2s_c3d" ("nipype.interfaces.c3.C3dAffineTool"), a CommandLine Interface with command:
# c3d_affine_tool -ref /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/seg/sub-ID42_ses-1_T1_MPRAGE_T1_brain_restore.nii.gz -src /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/mean/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_mcf_mean_reg.nii.gz /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/func2struc/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_mcf_mean_reg_flirt.mat -fsl2ras -oitk /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/f2s_c3d/affine.txt
# 200511-15:48:41,972 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.f2s_c3d".
# 200511-15:48:43,509 nipype.workflow INFO:
# 	 [Job 19] Completed (preproc.coreg.f2s_c3d).
# 200511-15:48:43,512 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.reg
# 200511-16:23:27,151 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.reg".
# 200511-16:23:27,207 nipype.workflow INFO:
# 	 [Job 4] Completed (preproc.coreg.reg).
# 200511-16:23:27,210 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 6/6.
# 200511-16:23:27,249 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.regbet".
# 200511-16:23:27,256 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.merge1".
# 200511-16:23:27,255 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.regbet" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regbet".
# 200511-16:23:27,258 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.merge1" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/merge1".
# 200511-16:23:27,259 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.regbet".
# 200511-16:23:27,262 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.coreg.merge1".
# 200511-16:23:27,270 nipype.workflow INFO:
# 	 [Node] Running "regbet" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/reg/transform_Warped.nii.gz /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regbet/transform_Warped_brain.nii.gz -f 0.37 -R
# 200511-16:23:27,270 nipype.workflow INFO:
# 	 [Node] Running "merge1" ("nipype.interfaces.utility.base.Merge")
# 200511-16:23:27,278 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.merge1".
# 200511-16:23:29,208 nipype.workflow INFO:
# 	 [Job 20] Completed (preproc.coreg.merge1).
# 200511-16:23:29,211 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.regressors.regbet
# 200511-16:23:29,279 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg.warp" in "/Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/warp".
# 200511-16:23:29,294 nipype.workflow INFO:
# 	 [Node] Running "warp" ("nipype.interfaces.ants.resampling.ApplyTransforms"), a CommandLine Interface with command:
# antsApplyTransforms --default-value 0 --float 0 --input /Users/James/Desktop/preproc/preproc/preproc/fproc/_ses_1_subject_id_42/moco/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg.nii.gz --input-image-type 3 --interpolation Linear --output sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans.nii.gz --reference-image /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz --transform /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/reg/transformComposite.h5 --transform /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/f2s_c3d/affine.txt
# 200511-16:23:30,582 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.regbet".
# 200511-16:23:31,212 nipype.workflow INFO:
# 	 [Job 5] Completed (preproc.regressors.regbet).
# 200511-16:23:31,214 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.warp
# 200511-16:23:31,255 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.regseg".
# 200511-16:23:31,262 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.regseg" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regseg".
# 200511-16:23:31,266 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.regseg".
# 200511-16:23:31,276 nipype.workflow INFO:
# 	 [Node] Running "regseg" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 -N --nopve -g -S 1 /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regseg/transform_Warped_brain.nii.gz
# 200511-16:23:33,216 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.regressors.regseg
#                        * preproc.coreg.warp
# 200511-16:23:41,547 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.regseg".
# 200511-16:23:43,227 nipype.workflow INFO:
# 	 [Job 6] Completed (preproc.regressors.regseg).
# 200511-16:23:43,231 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.warp
# 200511-16:23:43,286 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.subcortgm2".
# 200511-16:23:43,291 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.subcortgm".
# 200511-16:23:43,292 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.subcortgm2" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/subcortgm2".
# 200511-16:23:43,295 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.subcortgm" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/subcortgm".
# 200511-16:23:43,296 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.subcortgm2".
# 200511-16:23:43,299 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.subcortgm".
# 200511-16:23:43,309 nipype.workflow INFO:
# 	 [Node] Running "subcortgm2" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regseg/transform_Warped_brain_seg_2.nii.gz -sub /Users/James/Psilodep/subcortical_gm_mask/subcortical_gm_mask_bin.nii.gz -bin /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/subcortgm2/transform_Warped_brain_seg_2_maths.nii.gz
# 200511-16:23:43,310 nipype.workflow INFO:
# 	 [Node] Running "subcortgm" ("nipype.interfaces.fsl.maths.BinaryMaths"), a CommandLine Interface with command:
# fslmaths /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/regseg/transform_Warped_brain_seg_0.nii.gz -sub /Users/James/Psilodep/subcortical_gm_mask/subcortical_gm_mask_bin.nii.gz -bin /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/subcortgm/transform_Warped_brain_seg_0_maths.nii.gz
# 200511-16:23:43,567 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.subcortgm".
# 200511-16:23:43,621 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.subcortgm2".
# 200511-16:23:45,227 nipype.workflow INFO:
# 	 [Job 7] Completed (preproc.regressors.subcortgm2).
# 200511-16:23:45,229 nipype.workflow INFO:
# 	 [Job 10] Completed (preproc.regressors.subcortgm).
# 200511-16:23:45,232 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.warp
# 200511-16:23:45,276 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.fillwm".
# 200511-16:23:45,280 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.fillcsf".
# 200511-16:23:45,280 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.fillwm" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/fillwm".
# 200511-16:23:45,282 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.fillwm".
# 200511-16:23:45,284 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.fillcsf" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/fillcsf".
# 200511-16:23:45,287 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.fillcsf".
# 200511-16:23:45,292 nipype.workflow INFO:
# 	 [Node] Running "fillwm" ("nipype.interfaces.afni.utils.MaskTool"), a CommandLine Interface with command:
# 3dmask_tool -fill_holes -prefix transform_Warped_brain_seg_2_maths_mask.nii.gz -input /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/fillwm/transform_Warped_brain_seg_2_maths.nii.gz
# 200511-16:23:45,296 nipype.workflow INFO:
# 	 [Node] Running "fillcsf" ("nipype.interfaces.afni.utils.MaskTool"), a CommandLine Interface with command:
# 3dmask_tool -fill_holes -prefix transform_Warped_brain_seg_0_maths_mask.nii.gz -input /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/fillcsf/transform_Warped_brain_seg_0_maths.nii.gz
# 200511-16:23:47,230 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.80/14.40, Free processors: 3/6.
#                      Currently running:
#                        * preproc.regressors.fillcsf
#                        * preproc.regressors.fillwm
#                        * preproc.coreg.warp
# 200511-16:23:54,259 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.fillcsf".
# 200511-16:23:54,299 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.fillwm".
# 200511-16:23:55,244 nipype.workflow INFO:
# 	 [Job 8] Completed (preproc.regressors.fillwm).
# 200511-16:23:55,247 nipype.workflow INFO:
# 	 [Job 11] Completed (preproc.regressors.fillcsf).
# 200511-16:23:55,251 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.warp
# 200511-16:23:55,303 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.erowm".
# 200511-16:23:55,308 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.erocsf".
# 200511-16:23:55,307 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.erowm" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erowm".
# 200511-16:23:55,310 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.erowm".
# 200511-16:23:55,313 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.erocsf" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erocsf".
# 200511-16:23:55,316 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.erocsf".
# 200511-16:23:55,321 nipype.workflow INFO:
# 	 [Node] Running "erowm" ("nipype.interfaces.afni.utils.MaskTool"), a CommandLine Interface with command:
# 3dmask_tool -dilate_inputs -1 -prefix transform_Warped_brain_seg_2_maths_mask_mask.nii.gz -input /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erowm/transform_Warped_brain_seg_2_maths_mask.nii.gz
# 200511-16:23:55,327 nipype.workflow INFO:
# 	 [Node] Running "erocsf" ("nipype.interfaces.afni.utils.MaskTool"), a CommandLine Interface with command:
# 3dmask_tool -dilate_inputs -1 -prefix transform_Warped_brain_seg_0_maths_mask_mask.nii.gz -input /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erocsf/transform_Warped_brain_seg_0_maths_mask.nii.gz
# 200511-16:23:55,496 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.erocsf".
# 200511-16:23:55,497 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.erowm".
# 200511-16:23:57,243 nipype.workflow INFO:
# 	 [Job 9] Completed (preproc.regressors.erowm).
# 200511-16:23:57,245 nipype.workflow INFO:
# 	 [Job 12] Completed (preproc.regressors.erocsf).
# 200511-16:23:57,248 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.coreg.warp
# 200511-16:26:27,217 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg.warp".
# 200511-16:26:27,477 nipype.workflow INFO:
# 	 [Job 21] Completed (preproc.coreg.warp).
# 200511-16:26:27,480 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 6/6.
# 200511-16:26:27,541 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.localwm".
# 200511-16:26:27,588 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.meancsf".
# 200511-16:26:27,611 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.scrub.premean" in "/Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/premean".
# 200511-16:26:27,689 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.meancsf" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/meancsf".
# 200511-16:26:27,697 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.meancsf".
# 200511-16:26:27,693 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.localwm" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/localwm".
# 200511-16:26:27,704 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.localwm".
# 200511-16:26:27,706 nipype.workflow INFO:
# 	 [Node] Running "premean" ("nipype.interfaces.afni.utils.TStat"), a CommandLine Interface with command:
# 3dTstat -mean -prefix sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans_tstat.nii.gz /Users/James/Desktop/preproc/preproc/scrub/_ses_1_subject_id_42/premean/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans.nii.gz
# 200511-16:26:27,715 nipype.workflow INFO:
# 	 [Node] Running "meancsf" ("nipype.interfaces.fsl.utils.ImageMeants"), a CommandLine Interface with command:
# fslmeants -i /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/warp/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans.nii.gz -m /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erocsf/transform_Warped_brain_seg_0_maths_mask_mask.nii.gz --order=1 -o /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/meancsf/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans_ts.txt
# 200511-16:26:27,729 nipype.workflow INFO:
# 	 [Node] Running "localwm" ("nipype.interfaces.afni.utils.Localstat"), a CommandLine Interface with command:
# 3dLocalstat -prefix sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans_localstat.nii.gz -mask /Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/erowm/transform_Warped_brain_seg_2_maths_mask_mask.nii.gz -nbhd 'SPHERE(25.0)' -use_nonmask -stat mean /Users/James/Desktop/preproc/preproc/coreg/_ses_1_subject_id_42/warp/sub-ID42_ses-1_resting_state_fmri_roi_despike_tshift_volreg_trans.nii.gz
# 200511-16:26:29,481 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.80/14.40, Free processors: 3/6.
#                      Currently running:
#                        * preproc.regressors.meancsf
#                        * preproc.regressors.localwm
#                        * preproc.scrub.premean
# 200511-16:27:06,896 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.meancsf".
# 200511-16:27:07,528 nipype.workflow INFO:
# 	 [Job 31] Completed (preproc.regressors.meancsf).
# 200511-16:27:07,532 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.regressors.localwm
#                        * preproc.scrub.premean
# 200511-16:27:07,589 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.bpf_dt_csf".
# 200511-16:27:07,649 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.regressors.bpf_dt_csf" in "/Users/James/Desktop/preproc/preproc/regressors/_ses_1_subject_id_42/bpf_dt_csf".
# 200511-16:27:07,663 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.regressors.bpf_dt_csf".
# 200511-16:27:07,676 nipype.workflow INFO:
# 	 [Node] Running "bpf_dt_csf" ("__main__.CSFbpfdt")
# 200511-16:27:09,533 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.80/14.40, Free processors: 3/6.
#                      Currently running:
#                        * preproc.regressors.bpf_dt_csf
#                        * preproc.regressors.localwm
#                        * preproc.scrub.premean
# 200511-16:27:15,547 nipype.workflow INFO:
# 	 [Node] Finished "preproc.scrub.premean".
# 200511-16:27:17,540 nipype.workflow INFO:
# 	 [Job 22] Completed (preproc.scrub.premean).
# 200511-16:27:17,544 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.regressors.bpf_dt_csf
#                        * preproc.regressors.localwm
# 200511-16:27:27,988 nipype.workflow INFO:
# 	 [Node] Finished "preproc.regressors.bpf_dt_csf".
# 200511-16:27:29,549 nipype.workflow INFO:
# 	 [Job 32] Completed (preproc.regressors.bpf_dt_csf).
# 200511-16:27:29,553 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.regressors.localwm
# 200511-16:27:29,633 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.clean.concat" in "/Users/James/Desktop/preproc/preproc/clean/_ses_1_subject_id_42/concat".
# 200511-16:27:29,663 nipype.workflow INFO:
# 	 [Node] Running "concat" ("__main__.ConcatModel")
# 200511-16:27:31,555 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 4/6.
#                      Currently running:
#                        * preproc.clean.concat
#                        * preproc.regressors.localwm
# 200511-16:27:42,77 nipype.workflow INFO:
# 	 [Node] Finished "preproc.clean.concat".
# 200511-16:27:43,560 nipype.workflow INFO:
# 	 [Job 34] Completed (preproc.clean.concat).
# 200511-16:27:43,563 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 5/6.
#                      Currently running:
#                        * preproc.regressors.localwm
# Process ForkProcess-6:
# Process ForkProcess-1:
# Process ForkProcess-2:
# Process ForkProcess-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-4:
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
# exception calling callback for <Future at 0x11d86b810 state=finished raised BrokenProcessPool>
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/_base.py", line 324, in _invoke_callbacks
#     callback(self)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 159, in _async_callback
#     result = args.result()
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/James/opt/anaconda3/lib/python3.7/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/James/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-5802bbc08d0b>", line 1, in <module>
#     preproc.run('MultiProc', plugin_args={'n_procs' : 6})
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py", line 632, in run
#     runner.run(execgraph, updatehash=updatehash, config=self.config)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py", line 189, in run
#     sleep(max(0, sleep_til - time()))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/James/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/James/opt/anaconda3/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/James/opt/anaconda3/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
